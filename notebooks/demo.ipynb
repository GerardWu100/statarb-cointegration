# %% [markdown]
# # Notebook Wrapper
#
# This notebook stays thin by calling the split Python backend in `src/`.
# The original notebook is preserved unchanged in `docs/reference/`.

# %%
from statarb_cointegration.pipeline import run_pipeline

context = run_pipeline()
